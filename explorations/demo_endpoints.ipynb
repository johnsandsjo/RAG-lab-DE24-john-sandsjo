# %% [markdown]
# # Demo endpoints

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv

base_url = f"https://rag-youtube.azurewebsites.net/"

# %% [markdown]
# ## Main endpoint (rag/query)

# %%
endpoint = f"rag/query?code={os.getenv('FUNCTION_APP_API')}"

main_response = requests.post(url=base_url+endpoint, json={"prompt" : "Video about sql"})
main_response.json()
# Out:
# {'user_query': 'Video about sql',
#  'bot_response': {'video_title': 'sql analytics course with duckdb - set theory part 2 (using sakila)',
#   'video_link': 'https://www.youtube.com/@AIgineer',
#   'answer': 'Ro Båt my friend!\n\nI\'ve found a video for you titled "sql analytics course with duckdb - set theory part 2 (using sakila)".\n\nThis video dives deep into SQL set operations using the Sakila database within DuckDB. It\'s a fantastic resource for understanding how to combine and compare result sets effectively. The video covers: \n\n*   **Ingesting the Sakila SQLite database into DuckDB:** A practical demonstration of how to get your data ready for analysis. DuckDB is a powerful analytical database, perfect for local data exploration, and its ability to read various formats like SQLite is a huge plus for data engineers.\n*   **Exploratory Data Analysis (EDA):** You\'ll learn how to explore a rich dataset like Sakila, understanding table structures and relationships, including the concept of bridge tables.\n*   **Set Operations (UNION, INTERSECT, UNION ALL):** The core of the video, explaining these crucial SQL constructs with hands-on examples. Set operations are fundamental for merging distinct rows, finding common elements, or combining all rows from multiple queries, offering a different approach to data integration compared to joins.\n\nMastering SQL set theory is a cornerstone for any aspiring data or AI engineer, as it empowers you to write more efficient and expressive queries for data manipulation and aggregation. Understanding these concepts will significantly boost your analytical capabilities!\n\nCheck it out here: https://www.youtube.com/@AIgineer'},
#  'history': [{'parts': [{'content': '\n        You are an expert Youtuber in Data Engineering and AI Engineering.\n        Always start with the greeting; "Ro Båt my friend!"\n        Always use the retrieved knowledge of the Youtube transcripts from your tool to answer the question. \n        Always point to the video title you are referring to.\n        But do add more flavor from your expertise about the subject, keep it brief.\n        ',
#      'timestamp': '2025-12-11T13:42:46.092631+00:00',
#      'dynamic_ref': None,
#      'part_kind': 'system-prompt'},
#     {'content': 'Video about sql',
#      'timestamp': '2025-12-11T13:42:46.092641+00:00',
#      'part_kind': 'user-prompt'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': '4604b251-2ab5-4e99-8cf6-c135dbeda338',
#    'metadata': None},
#   {'parts': [{'tool_name': 'retrieve_matching_video',
#      'args': {'query': 'sql'},
#      'tool_call_id': 'pyd_ai_8bda2fa92af74b90901c6d89905e34f5',
#      'id': None,
#      'provider_details': {'thought_signature': ''},
#      'part_kind': 'tool-call'}],
#    'usage': {'input_tokens': 223,
#     'cache_write_tokens': 0,
#     'cache_read_tokens': 0,
#     'output_tokens': 65,
#     'input_audio_tokens': 0,
#     'cache_audio_read_tokens': 0,
#     'output_audio_tokens': 0,
#     'details': {'thoughts_tokens': 48, 'text_prompt_tokens': 223}},
#    'model_name': 'gemini-2.5-flash',
#    'timestamp': '2025-12-11T13:42:46.962072+00:00',
#    'kind': 'response',
#    'provider_name': 'google-gla',
#    'provider_details': {'finish_reason': 'STOP'},
#    'provider_response_id': 'Vso6af-xMrzbvdIP-b_x8AU',
#    'finish_reason': 'stop',
#    'run_id': '4604b251-2ab5-4e99-8cf6-c135dbeda338',
#    'metadata': None},
#   {'parts': [{'tool_name': 'retrieve_matching_video',
#      'content': "\n        Video title: sql analytics course with duckdb - set theory part 2 (using sakila) (1),\n        Content: # SQL analytics course with DuckDB - set theory part 2 (using Sakila)\n\n[00:00:00] Hello and welcome to this video, which is part two of the set operations in the coding. Hands on part two. Here we will instead, like in ~~the, before ~~the first video, we generated some data or we inserted some data and did some set operations. And that was like very simple data to work with.\n\nHowever, now we'll use this Quila database, and this is more. ~~Like very big da, ~~not very big database, . It ~~has ~~has several tables and we will show how to use different set operations in the Quila database. Since this video, it's the first time we'll work with the Quila database.\n\nI will show you ~~from ~~how you will ingest the data into Duct DB to work with, because this is originally my SQL database that I have created~~ however, ~~in Kaggle, which we will go to soon. You can download the database file, which has been ported to SQL light and for us we need to [00:01:00] be able to read that database.\n\n~~Yes.~~\n\n**Kokchun Giang-1:** here I am in the browser and you can search a Esq Light Quila sample database and you will get you'll come into here in Kaggle and then just download this database and you will get an archive zip. Unzip it and copy that folder into Visual Studio Code. I'll meet you in Visual Studio Code and I will show you this.\n\n**Kokchun Giang-2:** here I am in Visual Studio Code, and you can see I have copied in the folder into a data folder. However, ~~this is ~~here we have a lot of SQL files to actually generate ~~this ~~this data in SQ light, but I won't need that, ~~I will just delete that one. ~~Read me txt. It's good to have if you want to read more about the Takeda database.\n\nBasically it's a fixes database designed to represent a DVD rental store. That is what you need to know. And then we have the PNG here, right? This is the actual ski [00:02:00] mass. ~~The, this or ~~this is the relationship model the data model. You can see as a entity relationship diagram.\n\nYou can see the entities and. What type, these are the tables and what type of columns they have and how they're connected to each other. I won't go into detail how this work because this is more the scope of a data modeling course. Right now we are ~~in ~~working with ~~SKL ~~and Duct db. What I want to do now is to read this~~ ESQ ~~Light database into D db.\n\nTo do this, we do like this. I start a new folder. I call it SQL, and inside this folder, I will create a file called Load ~~ula sql, and ~~to load ~~ula ~~in~~ induc ~~db. What you need to do is. Install SQ light. This is an extension. We need to install it, and then we need to load SQ light [00:03:00] extension.\n\n? And after you've done that, you do call this sq light underscore attach. And here we need to find the actual database. This is the database. And I will run this from my root folder. It means that I will see it from data. I see data and going in there, I will go into Escal, light dash quila, do tb.\n\n, And that is it. I will save this one. And what we'll do now, I'll close this. I don't like this. Remove that one. , Let's do DAC db quila Duck db and I will do input redirection. Go into SQL load sa sq. I run this one and it says Success, success Bullion. Several rows. , Let's.\n\nTake a look if it's successful [00:04:00] or not. Ddb ULA ddb. Yes. Desk. Now you can say, wow, cool. I've gotten all ~~the ~~the tables that I want, right? These are all tables. And let's do, for example, from film. And you can see ah, a thousand rows. Ah, great. It works as we expect it to do. , Now I'll close this down and I will open this up in the ui.\n\nDuck db dash ui, ula duck db.\n\n**Kokchun Giang-4:** Since this is the first time we're working with Quila database, we will use do some EDA first. Exploratory data analysis. However, let's create a few scripts in  ...
#      'tool_call_id': 'pyd_ai_8bda2fa92af74b90901c6d89905e34f5',
#      'metadata': None,
#      'timestamp': '2025-12-11T13:42:48.373112+00:00',
#      'part_kind': 'tool-return'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': '4604b251-2ab5-4e99-8cf6-c135dbeda338',
#    'metadata': None},
#   {'parts': [{'tool_name': 'final_result',
#      'args': {'video_link': 'https://www.youtube.com/@AIgineer',
#       'video_title': 'sql analytics course with duckdb - set theory part 2 (using sakila)',
#       'answer': 'Ro Båt my friend!\n\nI\'ve found a video for you titled "sql analytics course with duckdb - set theory part 2 (using sakila)".\n\nThis video dives deep into SQL set operations using the Sakila database within DuckDB. It\'s a fantastic resource for understanding how to combine and compare result sets effectively. The video covers: \n\n*   **Ingesting the Sakila SQLite database into DuckDB:** A practical demonstration of how to get your data ready for analysis. DuckDB is a powerful analytical database, perfect for local data exploration, and its ability to read various formats like SQLite is a huge plus for data engineers.\n*   **Exploratory Data Analysis (EDA):** You\'ll learn how to explore a rich dataset like Sakila, understanding table structures and relationships, including the concept of bridge tables.\n*   **Set Operations (UNION, INTERSECT, UNION ALL):** The core of the video, explaining these crucial SQL constructs with hands-on examples. Set operations are fundamental for merging distinct rows, finding common elements, or combining all rows from multiple queries, offering a different approach to data integration compared to joins.\n\nMastering SQL set theory is a cornerstone for any aspiring data or AI engineer, as it empowers you to write more efficient and expressive queries for data manipulation and aggregation. Understanding these concepts will significantly boost your analytical capabilities!\n\nCheck it out here: https://www.youtube.com/@AIgineer'},
#      'tool_call_id': 'pyd_ai_5ef296d58b8044f6839f7f7ebd10c200',
#      'id': None,
#      'provider_details': {'thought_signature': '...'},
#      'part_kind': 'tool-call'}],
#    'usage': {'input_tokens': 4456,
#     'cache_write_tokens': 0,
#     'cache_read_tokens': 0,
#     'output_tokens': 771,
#     'input_audio_tokens': 0,
#     'cache_audio_read_tokens': 0,
#     'output_audio_tokens': 0,
#     'details': {'thoughts_tokens': 406, 'text_prompt_tokens': 4456}},
#    'model_name': 'gemini-2.5-flash',
#    'timestamp': '2025-12-11T13:42:53.384191+00:00',
#    'kind': 'response',
#    'provider_name': 'google-gla',
#    'provider_details': {'finish_reason': 'STOP'},
#    'provider_response_id': 'Xco6aYvzEbvVvdIPnaPA6AU',
#    'finish_reason': 'stop',
#    'run_id': '4604b251-2ab5-4e99-8cf6-c135dbeda338',
#    'metadata': None},
#   {'parts': [{'tool_name': 'final_result',
#      'content': 'Final result processed.',
#      'tool_call_id': 'pyd_ai_5ef296d58b8044f6839f7f7ebd10c200',
#      'metadata': None,
#      'timestamp': '2025-12-11T13:42:53.384554+00:00',
#      'part_kind': 'tool-return'},
#     {'content': 'Video about sql',
#      'timestamp': '2025-12-11T13:46:13.912316+00:00',
#      'part_kind': 'user-prompt'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': None,
#    'metadata': None},
#   {'parts': [{'tool_name': 'retrieve_matching_video',
#      'args': {'query': 'sql'},
#      'tool_call_id': 'pyd_ai_91541f4f7d7440cb847a259e808cc34f',
#      'id': None,
#      'provider_details': None,
#      'part_kind': 'tool-call'}],
#    'usage': {'input_tokens': 4844,
#     'cache_write_tokens': 0,
#     'cache_read_tokens': 0,
#     'output_tokens': 17,
#     'input_audio_tokens': 0,
#     'cache_audio_read_tokens': 0,
#     'output_audio_tokens': 0,
#     'details': {'text_prompt_tokens': 4844}},
#    'model_name': 'gemini-2.5-flash',
#    'timestamp': '2025-12-11T13:46:14.802122+00:00',
#    'kind': 'response',
#    'provider_name': 'google-gla',
#    'provider_details': {'finish_reason': 'STOP'},
#    'provider_response_id': 'Jss6abqMK_PxnsEP_tOW8QE',
#    'finish_reason': 'stop',
#    'run_id': 'edc95949-2d04-4ace-93ab-95647dfcdf99',
#    'metadata': None},
#   {'parts': [{'tool_name': 'retrieve_matching_video',
#      'content': "\n        Video title: sql analytics course with duckdb - set theory part 2 (using sakila) (1),\n        Content: # SQL analytics course with DuckDB - set theory part 2 (using Sakila)\n\n[00:00:00] Hello and welcome to this video, which is part two of the set operations in the coding. Hands on part two. Here we will instead, like in ~~the, before ~~the first video, we generated some data or we inserted some data and did some set operations. And that was like very simple data to work with.\n\nHowever, now we'll use this Quila database, and this is more. ~~Like very big da, ~~not very big database, . It ~~has ~~has several tables and we will show how to use different set operations in the Quila database. Since this video, it's the first time we'll work with the Quila database.\n\nI will show you ~~from ~~how you will ingest the data into Duct DB to work with, because this is originally my SQL database that I have created~~ however, ~~in Kaggle, which we will go to soon. You can download the database file, which has been ported to SQL light and for us we need to [00:01:00] be able to read that database.\n\n~~Yes.~~\n\n**Kokchun Giang-1:** here I am in the browser and you can search a Esq Light Quila sample database and you will get you'll come into here in Kaggle and then just download this database and you will get an archive zip. Unzip it and copy that folder into Visual Studio Code. I'll meet you in Visual Studio Code and I will show you this.\n\n**Kokchun Giang-2:** here I am in Visual Studio Code, and you can see I have copied in the folder into a data folder. However, ~~this is ~~here we have a lot of SQL files to actually generate ~~this ~~this data in SQ light, but I won't need that, ~~I will just delete that one. ~~Read me txt. It's good to have if you want to read more about the Takeda database.\n\nBasically it's a fixes database designed to represent a DVD rental store. That is what you need to know. And then we have the PNG here, right? This is the actual ski [00:02:00] mass. ~~The, this or ~~this is the relationship model the data model. You can see as a entity relationship diagram.\n\nYou can see the entities and. What type, these are the tables and what type of columns they have and how they're connected to each other. I won't go into detail how this work because this is more the scope of a data modeling course. Right now we are ~~in ~~working with ~~SKL ~~and Duct db. What I want to do now is to read this~~ ESQ ~~Light database into D db.\n\nTo do this, we do like this. I start a new folder. I call it SQL, and inside this folder, I will create a file called Load ~~ula sql, and ~~to load ~~ula ~~in~~ induc ~~db. What you need to do is. Install SQ light. This is an extension. We need to install it, and then we need to load SQ light [00:03:00] extension.\n\n? And after you've done that, you do call this sq light underscore attach. And here we need to find the actual database. This is the database. And I will run this from my root folder. It means that I will see it from data. I see data and going in there, I will go into Escal, light dash quila, do tb.\n\n, And that is it. I will save this one. And what we'll do now, I'll close this. I don't like this. Remove that one. , Let's do DAC db quila Duck db and I will do input redirection. Go into SQL load sa sq. I run this one and it says Success, success Bullion. Several rows. , Let's.\n\nTake a look if it's successful [00:04:00] or not. Ddb ULA ddb. Yes. Desk. Now you can say, wow, cool. I've gotten all ~~the ~~the tables that I want, right? These are all tables. And let's do, for example, from film. And you can see ah, a thousand rows. Ah, great. It works as we expect it to do. , Now I'll close this down and I will open this up in the ui.\n\nDuck db dash ui, ula duck db.\n\n**Kokchun Giang-4:** Since this is the first time we're working with Quila database, we will use do some EDA first. Exploratory data analysis. However, let's create a few scripts in  ...
#      'tool_call_id': 'pyd_ai_91541f4f7d7440cb847a259e808cc34f',
#      'metadata': None,
#      'timestamp': '2025-12-11T13:46:15.402762+00:00',
#      'part_kind': 'tool-return'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': 'edc95949-2d04-4ace-93ab-95647dfcdf99',
#    'metadata': None},
#   {'parts': [{'tool_name': 'final_result',
#      'args': {'answer': 'Ro Båt my friend!\n\nI\'ve found a video for you titled "sql analytics course with duckdb - set theory part 2 (using sakila)".\n\nThis video dives deep into SQL set operations using the Sakila database within DuckDB. It\'s a fantastic resource for understanding how to combine and compare result sets effectively. The video covers: \n\n*   **Ingesting the Sakila SQLite database into DuckDB:** A practical demonstration of how to get your data ready for analysis. DuckDB is a powerful analytical database, perfect for local data exploration, and its ability to read various formats like SQLite is a huge plus for data engineers.\n*   **Exploratory Data Analysis (EDA):** You\'ll learn how to explore a rich dataset like Sakila, understanding table structures and relationships, including the concept of bridge tables.\n*   **Set Operations (UNION, INTERSECT, UNION ALL):** The core of the video, explaining these crucial SQL constructs with hands-on examples. Set operations are fundamental for merging distinct rows, finding common elements, or combining all rows from multiple queries, offering a different approach to data integration compared to joins.\n\nMastering SQL set theory is a cornerstone for any aspiring data or AI engineer, as it empowers you to write more efficient and expressive queries for data manipulation and aggregation. Understanding these concepts will significantly boost your analytical capabilities!\n\nCheck it out here: https://www.youtube.com/@AIgineer',
#       'video_title': 'sql analytics course with duckdb - set theory part 2 (using sakila)',
#       'video_link': 'https://www.youtube.com/@AIgineer'},
#      'tool_call_id': 'pyd_ai_81b6f705956c4ea59bedea22bd77b8ec',
#      'id': None,
#      'provider_details': {'thought_signature': ''},
#      'part_kind': 'tool-call'}],
#    'usage': {'input_tokens': 9077,
#     'cache_write_tokens': 0,
#     'cache_read_tokens': 4762,
#     'output_tokens': 418,
#     'input_audio_tokens': 0,
#     'cache_audio_read_tokens': 0,
#     'output_audio_tokens': 0,
#     'details': {'cached_content_tokens': 4762,
#      'thoughts_tokens': 53,
#      'text_prompt_tokens': 9077,
#      'text_cache_tokens': 4762}},
#    'model_name': 'gemini-2.5-flash',
#    'timestamp': '2025-12-11T13:46:17.810590+00:00',
#    'kind': 'response',
#    'provider_name': 'google-gla',
#    'provider_details': {'finish_reason': 'STOP'},
#    'provider_response_id': 'Kcs6aYHSK_rinsEPhqnl4Qg',
#    'finish_reason': 'stop',
#    'run_id': 'edc95949-2d04-4ace-93ab-95647dfcdf99',
#    'metadata': None},
#   {'parts': [{'tool_name': 'final_result',
#      'content': 'Final result processed.',
#      'tool_call_id': 'pyd_ai_81b6f705956c4ea59bedea22bd77b8ec',
#      'metadata': None,
#      'timestamp': '2025-12-11T13:46:17.810896+00:00',
#      'part_kind': 'tool-return'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': 'edc95949-2d04-4ace-93ab-95647dfcdf99',
#    'metadata': None},
#   {'parts': [{'content': 'Video about sql',
#      'timestamp': '2025-12-11T13:47:26.707908+00:00',
#      'part_kind': 'user-prompt'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': 'c027620e-84b0-4841-a0a1-d7f28fe02a72',
#    'metadata': None},
#   {'parts': [{'tool_name': 'retrieve_matching_video',
#      'args': {'query': 'sql'},
#      'tool_call_id': 'pyd_ai_a0a5c3351cef4cdf8809962468ec7bb3',
#      'id': None,
#      'provider_details': None,
#      'part_kind': 'tool-call'}],
#    'usage': {'input_tokens': 9465,
#     'cache_write_tokens': 0,
#     'cache_read_tokens': 0,
#     'output_tokens': 17,
#     'input_audio_tokens': 0,
#     'cache_audio_read_tokens': 0,
#     'output_audio_tokens': 0,
#     'details': {'text_prompt_tokens': 9465}},
#    'model_name': 'gemini-2.5-flash',
#    'timestamp': '2025-12-11T13:47:27.670211+00:00',
#    'kind': 'response',
#    'provider_name': 'google-gla',
#    'provider_details': {'finish_reason': 'STOP'},
#    'provider_response_id': 'b8s6afGhIv68nsEPv8_7qAQ',
#    'finish_reason': 'stop',
#    'run_id': 'c027620e-84b0-4841-a0a1-d7f28fe02a72',
#    'metadata': None},
#   {'parts': [{'tool_name': 'retrieve_matching_video',
#      'content': "\n        Video title: sql analytics course with duckdb - set theory part 2 (using sakila) (1),\n        Content: # SQL analytics course with DuckDB - set theory part 2 (using Sakila)\n\n[00:00:00] Hello and welcome to this video, which is part two of the set operations in the coding. Hands on part two. Here we will instead, like in ~~the, before ~~the first video, we generated some data or we inserted some data and did some set operations. And that was like very simple data to work with.\n\nHowever, now we'll use this Quila database, and this is more. ~~Like very big da, ~~not very big database, . It ~~has ~~has several tables and we will show how to use different set operations in the Quila database. Since this video, it's the first time we'll work with the Quila database.\n\nI will show you ~~from ~~how you will ingest the data into Duct DB to work with, because this is originally my SQL database that I have created~~ however, ~~in Kaggle, which we will go to soon. You can download the database file, which has been ported to SQL light and for us we need to [00:01:00] be able to read that database.\n\n~~Yes.~~\n\n**Kokchun Giang-1:** here I am in the browser and you can search a Esq Light Quila sample database and you will get you'll come into here in Kaggle and then just download this database and you will get an archive zip. Unzip it and copy that folder into Visual Studio Code. I'll meet you in Visual Studio Code and I will show you this.\n\n**Kokchun Giang-2:** here I am in Visual Studio Code, and you can see I have copied in the folder into a data folder. However, ~~this is ~~here we have a lot of SQL files to actually generate ~~this ~~this data in SQ light, but I won't need that, ~~I will just delete that one. ~~Read me txt. It's good to have if you want to read more about the Takeda database.\n\nBasically it's a fixes database designed to represent a DVD rental store. That is what you need to know. And then we have the PNG here, right? This is the actual ski [00:02:00] mass. ~~The, this or ~~this is the relationship model the data model. You can see as a entity relationship diagram.\n\nYou can see the entities and. What type, these are the tables and what type of columns they have and how they're connected to each other. I won't go into detail how this work because this is more the scope of a data modeling course. Right now we are ~~in ~~working with ~~SKL ~~and Duct db. What I want to do now is to read this~~ ESQ ~~Light database into D db.\n\nTo do this, we do like this. I start a new folder. I call it SQL, and inside this folder, I will create a file called Load ~~ula sql, and ~~to load ~~ula ~~in~~ induc ~~db. What you need to do is. Install SQ light. This is an extension. We need to install it, and then we need to load SQ light [00:03:00] extension.\n\n? And after you've done that, you do call this sq light underscore attach. And here we need to find the actual database. This is the database. And I will run this from my root folder. It means that I will see it from data. I see data and going in there, I will go into Escal, light dash quila, do tb.\n\n, And that is it. I will save this one. And what we'll do now, I'll close this. I don't like this. Remove that one. , Let's do DAC db quila Duck db and I will do input redirection. Go into SQL load sa sq. I run this one and it says Success, success Bullion. Several rows. , Let's.\n\nTake a look if it's successful [00:04:00] or not. Ddb ULA ddb. Yes. Desk. Now you can say, wow, cool. I've gotten all ~~the ~~the tables that I want, right? These are all tables. And let's do, for example, from film. And you can see ah, a thousand rows. Ah, great. It works as we expect it to do. , Now I'll close this down and I will open this up in the ui.\n\nDuck db dash ui, ula duck db.\n\n**Kokchun Giang-4:** Since this is the first time we're working with Quila database, we will use do some EDA first. Exploratory data analysis. However, let's create a few scripts in  ...
#      'tool_call_id': 'pyd_ai_a0a5c3351cef4cdf8809962468ec7bb3',
#      'metadata': None,
#      'timestamp': '2025-12-11T13:47:27.948910+00:00',
#      'part_kind': 'tool-return'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': 'c027620e-84b0-4841-a0a1-d7f28fe02a72',
#    'metadata': None},
#   {'parts': [{'tool_name': 'final_result',
#      'args': {'video_link': 'https://www.youtube.com/@AIgineer',
#       'video_title': 'sql analytics course with duckdb - set theory part 2 (using sakila)',
#       'answer': 'Ro Båt my friend!\n\nI\'ve found a video for you titled "sql analytics course with duckdb - set theory part 2 (using sakila)".\n\nThis video dives deep into SQL set operations using the Sakila database within DuckDB. It\'s a fantastic resource for understanding how to combine and compare result sets effectively. The video covers: \n\n*   **Ingesting the Sakila SQLite database into DuckDB:** A practical demonstration of how to get your data ready for analysis. DuckDB is a powerful analytical database, perfect for local data exploration, and its ability to read various formats like SQLite is a huge plus for data engineers.\n*   **Exploratory Data Analysis (EDA):** You\'ll learn how to explore a rich dataset like Sakila, understanding table structures and relationships, including the concept of bridge tables.\n*   **Set Operations (UNION, INTERSECT, UNION ALL):** The core of the video, explaining these crucial SQL constructs with hands-on examples. Set operations are fundamental for merging distinct rows, finding common elements, or combining all rows from multiple queries, offering a different approach to data integration compared to joins.\n\nMastering SQL set theory is a cornerstone for any aspiring data or AI engineer, as it empowers you to write more efficient and expressive queries for data manipulation and aggregation. Understanding these concepts will significantly boost your analytical capabilities!\n\nCheck it out here: https://www.youtube.com/@AIgineer'},
#      'tool_call_id': 'pyd_ai_66cfa4726a1c40b4adda80a6963c680c',
#      'id': None,
#      'provider_details': {'thought_signature': '...'},
#      'part_kind': 'tool-call'}],
#    'usage': {'input_tokens': 13698,
#     'cache_write_tokens': 0,
#     'cache_read_tokens': 8730,
#     'output_tokens': 424,
#     'input_audio_tokens': 0,
#     'cache_audio_read_tokens': 0,
#     'output_audio_tokens': 0,
#     'details': {'cached_content_tokens': 8730,
#      'thoughts_tokens': 59,
#      'text_prompt_tokens': 13698,
#      'text_cache_tokens': 8730}},
#    'model_name': 'gemini-2.5-flash',
#    'timestamp': '2025-12-11T13:47:31.557574+00:00',
#    'kind': 'response',
#    'provider_name': 'google-gla',
#    'provider_details': {'finish_reason': 'STOP'},
#    'provider_response_id': 'c8s6abzmHJumnsEPi9-IqAE',
#    'finish_reason': 'stop',
#    'run_id': 'c027620e-84b0-4841-a0a1-d7f28fe02a72',
#    'metadata': None},
#   {'parts': [{'tool_name': 'final_result',
#      'content': 'Final result processed.',
#      'tool_call_id': 'pyd_ai_66cfa4726a1c40b4adda80a6963c680c',
#      'metadata': None,
#      'timestamp': '2025-12-11T13:47:31.557916+00:00',
#      'part_kind': 'tool-return'}],
#    'instructions': None,
#    'kind': 'request',
#    'run_id': 'c027620e-84b0-4841-a0a1-d7f28fe02a72',
#    'metadata': None}]}

# %% [markdown]
# ## History endpoint

# %%
endpoint = f"rag/history?code={os.getenv('FUNCTION_APP_API')}"

history_response = requests.get(url=base_url+endpoint)
history_response.json()

# %% [markdown]
# ## Description generation endpoint

# %%
endpoint = f"rag/description-gen?code={os.getenv('FUNCTION_APP_API')}"

desc_response = requests.post(url=base_url+endpoint, json={"prompt" : "Video about sql"})
desc_response.json()

# %% [markdown]
# ## Keywords generator endpoint

# %%
endpoint = f"rag/keyword-gen?code={os.getenv('FUNCTION_APP_API')}"

keyword_response = requests.post(url=base_url+endpoint, json={"prompt" : "Video about sql"})
keyword_response.json()
